# %% [markdown]
# # Task 1: Data Preparation

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
# Start from here to write your code for Task 1. Please also feel free to add more cells in this ipynb file. 
#To read each individual dataframe
df_Manufacturer=pd.read_csv("Manufacturer.csv")

# %%
#To see first 5 items of the dataframe
df_Manufacturer.head()
# Out:
#    Unnamed: 0 Manufacturer
# 0           0         Ford
# 1           1         Ford
# 2           2   Volkswagen
# 3           3      Renault
# 4           4          BMW

# %%
df_Model=pd.read_csv("Model.csv")

# %%
df_Model.head()
# Out:
#    Unnamed: 0   Model
# 0           0   Focus
# 1           1  Fiesta
# 2           2    Golf
# 3           3    Clio
# 4           4    320i

# %%
df_Price=pd.read_csv("Price.csv")

# %%
df_Price.head()
# Out:
#    Unnamed: 0      Price
# 0           0  30.619322
# 1           1  18.532143
# 2           2  31.242154
# 3           3  22.100000
# 4           4  47.848370

# %%
df_Transmission=pd.read_csv("Transmission.csv")

# %%
df_Transmission.head()
# Out:
#    Unnamed: 0  Transmission
# 0           0      5.966102
# 1           1   5000.714286
# 2           2      6.164835
# 3           3      5.615385
# 4           4      6.444444

# %%
df_Power=pd.read_csv("Power.csv")

# %%
df_Power.head()
# Out:
#    Unnamed: 0       Power
# 0           0  -94.033898
# 1           1   68.571429
# 2           2  -89.461538
# 3           3   75.576923
# 4           4  126.111111

# %%
df_Engine=pd.read_csv("Engine CC.csv")

# %%
df_Engine.head()
# Out:
#    Unnamed: 0    Engine CC
# 0           0  1497.169492
# 1           1  1166.142857
# 2           2  1537.406593
# 3           3  1219.653846
# 4           4  1995.777778

# %%
df_Fuel=pd.read_csv("Fuel.csv")

# %%
df_Fuel.head()
# Out:
#    Unnamed: 0    Fuel
# 0           0  petrol
# 1           1  petrol
# 2           2  petrol
# 3           3  petrol
# 4           4  petrol

# %%
df_Male=pd.read_csv("Male.csv")

# %%
df_Male.head()
# Out:
#    Unnamed: 0    Male
# 0           0  814172
# 1           1  554879
# 2           2  483216
# 3           3  241287
# 4           4  408016

# %%
df_Female=pd.read_csv("Female.csv")

# %%
df_Female.head()
# Out:
#    Unnamed: 0  Female
# 0           0  422731
# 1           1  631666
# 2           2  310604
# 3           3  312556
# 4           4  115843

# %%
df_Unknown=pd.read_csv("Unknown.csv")

# %%
df_Unknown.head()
# Out:
#    Unnamed: 0 Unknown
# 0           0  56,487
# 1           1  54,057
# 2           2  47,563
# 3           3  28,004
# 4           4  29,125

# %%
df_Total=pd.read_csv("Total.csv")

# %%
df_Total.head()
# Out:
#    Unnamed: 0    Total
# 0           0  1293390
# 1           1  1240602
# 2           2   841383
# 3           3   581847
# 4           4   552984

# %%
#To store all dataframe into one list
df_all=[df_Model,df_Price,df_Transmission,df_Power,df_Engine,df_Fuel,df_Male,df_Female,df_Unknown,df_Total]

# %%
#Merging each dataframe to first dataframe using for loop as there is finite number of iteration
for col in range(0,len(df_all)):
    df_Manufacturer=df_Manufacturer.merge(df_all[col])
df_Manufacturer.head()
# Out:
#    Unnamed: 0 Manufacturer   Model      Price  Transmission       Power  \
# 0           0         Ford   Focus  30.619322      5.966102  -94.033898
# 1           1         Ford  Fiesta  18.532143   5000.714286   68.571429
# 2           2   Volkswagen    Golf  31.242154      6.164835  -89.461538
# 3           3      Renault    Clio  22.100000      5.615385   75.576923
# 4           4          BMW    320i  47.848370      6.444444  126.111111
#
#      Engine CC    Fuel    Male  Female Unknown    Total
# 0  1497.169492  petrol  814172  422731  56,487  1293390
# 1  1166.142857  petrol  554879  631666  54,057  1240602
# 2  1537.406593  petrol  483216  310604  47,563   841383
# 3  1219.653846  petrol  241287  312556  28,004   581847
# 4  1995.777778  petrol  408016  115843  29,125   552984

# %%
df_Merged=df_Manufacturer.copy()

# %%
#Data Cleaning
#To remove Unnamed: 0 column
df_Merged.drop("Unnamed: 0",axis=1,inplace=True)
df_Merged.head()
# Out:
#   Manufacturer   Model      Price  Transmission       Power    Engine CC  \
# 0         Ford   Focus  30.619322      5.966102  -94.033898  1497.169492
# 1         Ford  Fiesta  18.532143   5000.714286   68.571429  1166.142857
# 2   Volkswagen    Golf  31.242154      6.164835  -89.461538  1537.406593
# 3      Renault    Clio  22.100000      5.615385   75.576923  1219.653846
# 4          BMW    320i  47.848370      6.444444  126.111111  1995.777778
#
#      Fuel    Male  Female Unknown    Total
# 0  petrol  814172  422731  56,487  1293390
# 1  petrol  554879  631666  54,057  1240602
# 2  petrol  483216  310604  47,563   841383
# 3  petrol  241287  312556  28,004   581847
# 4  petrol  408016  115843  29,125   552984

# %%
#To check is there any null value
df_Merged.isnull().values.any()
# Out:
# True

# %%
#To check percentage of null values in each column
df_Merged.isna().sum()*100/len(df_Merged)
# Out:
# Manufacturer    0.016388
# Model           0.016388
# Price           0.081940
# Transmission    0.065552
# Power           0.081940
# Engine CC       0.065552
# Fuel            0.081940
# Male            0.065552
# Female          0.081940
# Unknown         0.081940
# Total           0.081940
# dtype: float64

# %%
#To find number of missing values on each column
pd.DataFrame( df_Merged.isnull().sum(), columns= ['Number of missing values'])
# Out:
#               Number of missing values
# Manufacturer                         1
# Model                                1
# Price                                5
# Transmission                         4
# Power                                5
# Engine CC                            4
# Fuel                                 5
# Male                                 4
# Female                               5
# Unknown                              5
# Total                                5

# %% [markdown]
# #### We have some null values in each column.

# %%
#To check index value of missing value
print (df_Merged[df_Merged.Price.isna()].index)
print (df_Merged[df_Merged.Transmission.isna()].index)
print (df_Merged[df_Merged.Power.isna()].index)
print (df_Merged[df_Merged["Engine CC"].isna()].index)
print (df_Merged[df_Merged.Fuel.isna()].index)
print (df_Merged[df_Merged.Male.isna()].index)
print (df_Merged[df_Merged.Female.isna()].index)
print (df_Merged[df_Merged.Unknown.isna()].index)
print (df_Merged[df_Merged.Total.isna()].index)
# Out:
# Int64Index([23, 32, 54, 65, 75], dtype='int64')
# Int64Index([23, 32, 54, 65], dtype='int64')
# Int64Index([23, 32, 54, 65, 75], dtype='int64')
# Int64Index([23, 32, 54, 65], dtype='int64')
# Int64Index([23, 32, 54, 65, 75], dtype='int64')
# Int64Index([23, 32, 54, 65], dtype='int64')
# Int64Index([23, 32, 54, 65, 75], dtype='int64')
# Int64Index([23, 32, 54, 65, 75], dtype='int64')
# Int64Index([23, 32, 54, 65, 75], dtype='int64')

# %% [markdown]
# #### As most of  missing values are from same rows(23,32,54,65,and 75), we can directly drop whole row.

# %%
#To drop all missing values
df_Merged.dropna(inplace=True)
df_Merged.isnull().sum()
# Out:
# Manufacturer    0
# Model           0
# Price           0
# Transmission    0
# Power           0
# Engine CC       0
# Fuel            0
# Male            0
# Female          0
# Unknown         0
# Total           0
# dtype: int64

# %%
#Again to check is there any null values
df_Merged.isnull().values.any()
# Out:
# False

# %% [markdown]
# So its confirm that there is no null values

# %%
#To reset index value
df_Merged.reset_index(inplace=True,drop=True)
df_Merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6097 entries, 0 to 6096
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Manufacturer  6097 non-null   object
#  1   Model         6097 non-null   object
#  2   Price         6097 non-null   float64
#  3   Transmission  6097 non-null   float64
#  4   Power         6097 non-null   float64
#  5   Engine CC     6097 non-null   float64
#  6   Fuel          6097 non-null   object
#  7   Male          6097 non-null   object
#  8   Female        6097 non-null   object
#  9   Unknown       6097 non-null   object
#  10  Total         6097 non-null   object
# dtypes: float64(4), object(7)
# memory usage: 524.1+ KB

# %%
# Checking for duplicate rows
df_Merged.duplicated().any()
# Out:
# False

# %% [markdown]
#  There are no duplicate rows

# %%
# Converting Male, Female, Unknown and Total to integer
df_Merged['Unknown'] = df_Merged['Unknown'].astype('str').str.replace(',', '').astype('int')
df_Merged
# Out:
#      Manufacturer     Model       Price  Transmission       Power  \
# 0            Ford     Focus   30.619322      5.966102  -94.033898
# 1            Ford    Fiesta   18.532143   5000.714286   68.571429
# 2      Volkswagen      Golf   31.242154      6.164835  -89.461538
# 3         Renault      Clio   22.100000      5.615385   75.576923
# 4             BMW      320i   47.848370      6.444444  126.111111
# ...           ...       ...         ...           ...         ...
# 6092   Land-Rover  Defender  108.747195      7.853659  207.609756
# 6093       Toyota      RAV4   43.548516      1.354839  137.774193
# 6094   Alfa-Romeo    Spider   55.200000      6.000000  163.500000
# 6095        Honda   Shuttle   30.081000      4.000000  110.000000
# 6096   Mitsubishi     Space   23.165158      3.947368   82.157895
#
#         Engine CC    Fuel    Male  Female  Unknown    Total
# 0     1497.169492  petrol  814172  422731    56487  1293390
# ...

# %%
df_Merged['Total'] = df_Merged['Total'].astype('str').str.replace(',', '').astype('int')
df_Merged
# Out:
#      Manufacturer     Model       Price  Transmission       Power  \
# 0            Ford     Focus   30.619322      5.966102  -94.033898
# 1            Ford    Fiesta   18.532143   5000.714286   68.571429
# 2      Volkswagen      Golf   31.242154      6.164835  -89.461538
# 3         Renault      Clio   22.100000      5.615385   75.576923
# 4             BMW      320i   47.848370      6.444444  126.111111
# ...           ...       ...         ...           ...         ...
# 6092   Land-Rover  Defender  108.747195      7.853659  207.609756
# 6093       Toyota      RAV4   43.548516      1.354839  137.774193
# 6094   Alfa-Romeo    Spider   55.200000      6.000000  163.500000
# 6095        Honda   Shuttle   30.081000      4.000000  110.000000
# 6096   Mitsubishi     Space   23.165158      3.947368   82.157895
#
#         Engine CC    Fuel    Male  Female  Unknown    Total
# 0     1497.169492  petrol  814172  422731    56487  1293390
# ...

# %%
df_Merged['Male'] = df_Merged['Male'].astype('str').str.replace(',', '').astype('int')
df_Merged
# Out:
#      Manufacturer     Model       Price  Transmission       Power  \
# 0            Ford     Focus   30.619322      5.966102  -94.033898
# 1            Ford    Fiesta   18.532143   5000.714286   68.571429
# 2      Volkswagen      Golf   31.242154      6.164835  -89.461538
# 3         Renault      Clio   22.100000      5.615385   75.576923
# 4             BMW      320i   47.848370      6.444444  126.111111
# ...           ...       ...         ...           ...         ...
# 6092   Land-Rover  Defender  108.747195      7.853659  207.609756
# 6093       Toyota      RAV4   43.548516      1.354839  137.774193
# 6094   Alfa-Romeo    Spider   55.200000      6.000000  163.500000
# 6095        Honda   Shuttle   30.081000      4.000000  110.000000
# 6096   Mitsubishi     Space   23.165158      3.947368   82.157895
#
#         Engine CC    Fuel    Male  Female  Unknown    Total
# 0     1497.169492  petrol  814172  422731    56487  1293390
# ...

# %%
df_Merged['Female'] = df_Merged['Female'].astype('str').str.replace(',', '').astype('int')
df_Merged
# Out:
#      Manufacturer     Model       Price  Transmission       Power  \
# 0            Ford     Focus   30.619322      5.966102  -94.033898
# 1            Ford    Fiesta   18.532143   5000.714286   68.571429
# 2      Volkswagen      Golf   31.242154      6.164835  -89.461538
# 3         Renault      Clio   22.100000      5.615385   75.576923
# 4             BMW      320i   47.848370      6.444444  126.111111
# ...           ...       ...         ...           ...         ...
# 6092   Land-Rover  Defender  108.747195      7.853659  207.609756
# 6093       Toyota      RAV4   43.548516      1.354839  137.774193
# 6094   Alfa-Romeo    Spider   55.200000      6.000000  163.500000
# 6095        Honda   Shuttle   30.081000      4.000000  110.000000
# 6096   Mitsubishi     Space   23.165158      3.947368   82.157895
#
#         Engine CC    Fuel    Male  Female  Unknown    Total
# 0     1497.169492  petrol  814172  422731    56487  1293390
# ...

# %%
#To store existing dataframe to new dataframe called 
df_Merged.to_csv('cleaned_car_buyers.csv', index=False)

# %%
#To read the stored csv file
df_cars=pd.read_csv("cleaned_car_buyers.csv")
df_cars.head(40)
# Out:
#    Manufacturer       Model          Price  Transmission       Power  \
# 0          Ford       Focus      30.619322      5.966102  -94.033898
# 1          Ford      Fiesta      18.532143   5000.714286   68.571429
# 2    Volkswagen        Golf      31.242154      6.164835  -89.461538
# 3       Renault        Clio      22.100000      5.615385   75.576923
# 4           BMW        320i      47.848370      6.444444  126.111111
# 5    Volkswagen        Polo      18.192500      5.074074   60.962963
# 6       Peugeot         206      20.033750      4.833333   71.333333
# 7          Ford      Mondeo      39.973750      1.750000  130.250000
# 8        Nissan       Micra      20.377609      4.869565   67.956522
# 9         Honda       Civic      29.942625      4.500000  106.225000
# 10         Ford         Ka+      15.460000      5.000000   60.800000
# 11      Renault      Megane      26.449887      5.408867   87.310345
# 12       Toyota       Yaris      20.720600      3.520000   74.400000
# ...

# %% [markdown]
# # Task 2: Data Exploration

# %% [markdown]
# ## Task 2.1

# %%
#Sording the complete dataframe by descending order on Totalcolumn
Sorted_df=df_cars.sort_values(axis=0,ascending=False,by='Total')
Sorted_df=Sorted_df.head(10)
Sorted_df
# Out:
#      Manufacturer   Model      Price  Transmission      Power    Engine CC  \
# 5276         Ford  Fiesta  18.532143      5.714286  68.571429  1166.142857
# 5501         Ford  Fiesta  18.532143      5.714286  68.571429  1166.142857
# 5034         Ford  Fiesta  18.532143      5.714286  68.571429  1166.142857
# 5502         Ford  Escort  16.208744      4.461538  63.564103  1650.205128
# 5913         Ford  Escort  16.208744      4.461538  63.564103  1650.205128
# 5277         Ford  Escort  16.208744      4.461538  63.564103  1650.205128
# 5716         Ford  Escort  16.208744      4.461538  63.564103  1650.205128
# 5717         Ford  Fiesta  18.532143      5.714286  68.571429  1166.142857
# 4777         Ford  Fiesta  18.532143      5.714286  68.571429  1166.142857
# 5914         Ford  Fiesta  18.532143      5.714286  68.571429  1166.142857
#
#         Fuel     Male  Female  Unknown    Total
# 5276  petrol   730276  789633    41603  1561512
# ...

# %%
#To plot bar graph 
Sorted_df[['Male','Female','Unknown','Model']].set_index('Model').plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='Model'>

# %%
#To calculate percentage of male, female,Unknown in Total
Male_Percentage=Sorted_df['Male']*100/Sorted_df['Total']
Female_Percentage=Sorted_df['Female']*100/Sorted_df['Total']
Unknown_Percentage=Sorted_df['Unknown']*100/Sorted_df['Total']
Gender_Percentage = pd.DataFrame([Sorted_df.Model,Male_Percentage, Female_Percentage, Unknown_Percentage]).T
Gender_Percentage.rename(columns={"Unnamed 0":"Male","Unnamed 1":"Female","Unnamed 2":"Unknown"},inplace=True)
Gender_Percentage
# Out:
#        Model       Male     Female   Unknown
# 5276  Fiesta  46.767236  50.568487  2.664277
# 5501  Fiesta  47.317107  50.180044  2.502849
# 5034  Fiesta  46.277681  50.845225  2.877093
# 5502  Escort  64.813358    32.8673  2.319342
# 5913  Escort  65.963592  32.076323  1.960084
# 5277  Escort  64.455684  33.106247  2.438069
# 5716  Escort  65.327931  32.535142  2.136926
# 5717  Fiesta  48.019889  49.674975  2.305136
# 4777  Fiesta  45.955944  50.885492  3.158564
# 5914  Fiesta  48.717969  49.112662  2.169369

# %% [markdown]
# ## Task 2.2

# %%
#To plot box plot on price and power
plt.subplot(1,2,1)
sns.boxplot(data=df_cars,x='Power')
plt.subplot(1,2,2)
sns.boxplot(data=df_cars,x='Price')
# Out:
# <AxesSubplot:xlabel='Price'>

# %%
#To plot scatter plot
fig, ax = plt.subplots()
ax.scatter(df_cars['Power'], df_cars['Price'])
ax.set_xlabel('Power')
ax.set_ylabel('Price')
plt.show()

# %%
#To create new dataframe with Power and Price
Outlier_df= pd.DataFrame([df_cars['Power'],df_cars['Price']]).T

# %%
#To find 1st quantile and 2nd quantile
Q1 = Outlier_df.quantile(0.25)
Q3 = Outlier_df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Power    51.607143
# Price    25.350631
# dtype: float64

# %%
#To find outliers
np.where((Outlier_df < (Q1 - 1.5 * IQR)) | (Outlier_df > (Q3 + 1.5 * IQR)))
# Out:
# (array([   0,    2,   26, ..., 6090, 6092, 6092], dtype=int64),
#  array([0, 0, 0, ..., 1, 0, 1], dtype=int64))

# %%
#To find non outliers
Outlier_df_out = Outlier_df[~((Outlier_df < (Q1 - 1.5 * IQR)) |(Outlier_df > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
#Replacing every outlier on the lower side by the lower whisker
for i, j in zip(np.where(Outlier_df < Q1 - 1.5 * IQR)[0], np.where(Outlier_df < Q1 - 1.5 * IQR)[1]): 
    
    whisker  = Q1 - 1.5 * IQR
    Outlier_df.iloc[i,j] = whisker[j] 
#Replacing every outlier on the upper side by the upper whisker
for i, j in zip(np.where(Outlier_df > Q3 + 1.5 * IQR)[0], np.where(Outlier_df > Q3 + 1.5 * IQR)[1]):
    
    whisker  = Q3 + 1.5 * IQR
    Outlier_df.iloc[i,j] = whisker[j]

# %%
#To replace negative value and 0 with None
Outlier_df[Outlier_df<=0]=None

# %%
#To drop all None value
Outlier_df.dropna(inplace=True)

# %%
Outlier_df.head()
# Out:
#         Power      Price
# 1   68.571429  18.532143
# 3   75.576923  22.100000
# 4  126.111111  47.848370
# 5   60.962963  18.192500
# 6   71.333333  20.033750

# %%
Outlier_df.shape
# Out:
# (6093, 2)

# %%
#To replace new power and price with original dataframe
df_cars['Power']=Outlier_df['Power']
df_cars['Price']=Outlier_df['Price']

# %%
#To plot box plot to check
sns.boxplot(data=df_cars,x='Price')
# Out:
# <AxesSubplot:xlabel='Price'>

# %%
sns.boxplot(data=df_cars,x='Price')
# Out:
# <AxesSubplot:xlabel='Price'>

# %% [markdown]
# ## Task 2.3

# %%
# Code goes after this line by adding cells
df_compare=df_cars.copy()

# %%
#Removing unnecessary column from dataframe 
df_compare.drop(columns=['Female','Unknown','Total'],inplace=True)

# %%
#Toplot scatter plot
fig, ax = plt.subplots(figsize=(16,8))   # setting the figure size of the plot
ax.scatter(df_compare['Male'], df_compare['Price'])  # scatter plot
ax.set_xlabel('Male')
ax.set_ylabel('Price')
plt.show()

# %%
ig, ax = plt.subplots(figsize=(16,8))   # setting the figure size of the plot
ax.scatter(df_compare['Male'], df_compare['Power'])  # scatter plot
ax.set_xlabel('Male')
ax.set_ylabel('Power')
plt.show()

# %%
ig, ax = plt.subplots(figsize=(16,8))   # setting the figure size of the plot
ax.scatter(df_compare['Male'], df_compare['Transmission'])  # scatter plot
ax.set_xlabel('Male')
ax.set_ylabel('Transmission')
plt.show()

# %%
ig, ax = plt.subplots(figsize=(16,8))   # setting the figure size of the plot
ax.scatter(df_compare['Male'], df_compare['Engine CC'])  # scatter plot
ax.set_xlabel('Male')
ax.set_ylabel('Engine CC')
plt.show()

# %%
sns.pairplot(df_cars.sample(400))
